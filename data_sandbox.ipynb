# %% [markdown]
# step 1 - identify hexes that fall within conus

# %% [markdown]
# step 2 - identify snapped to road point closest to center for all hexes

# %% [markdown]
# step 3 - execute ~650 'many to one' searches (not 650x649/2)
